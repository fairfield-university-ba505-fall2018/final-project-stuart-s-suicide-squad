# %% [markdown]
# # Stock Analysis Dashboard
# Brought to you by: Brian Walsh, Thomas Moroski and Stuart Weinstein
#
# Our goal was to develop an interactive dashboard where users can get descriptive statistics on any US stock.

# %%
#Initial Imports
import back_end as bk

# %% [markdown]
# ## 1) Please Enter a Symbol
# This block is used to get the stock symbol from the user and then generates a Pandas Df from the data. It then displays the head so we know it worked succesfully

# %%
#This block will loop through and ask the user for stock symbols they want to analyze. 'get_stocks' will promt the user for the symbols and return a list of them.
#'make_df' will make the dataframes based on the symbols, and return a list of dataframes. The for loop will simply print the first row of each DF so that we can confirm it worked.

symbols = bk.get_stocks() 
stock_dfs = bk.make_df(symbols)
stock_dfs_length = len(stock_dfs)
for symbol in range(0,stock_dfs_length):
    print(symbols[symbol])
    display(stock_dfs[symbol].head(1))
    display(stock_dfs[symbol].tail(1))
    bk.line()
# Out:
# Enter a stock symbol:  tsla
# Enter a stock symbol:  nvda
# Enter a stock symbol:  ge
# Enter a stock symbol:  fb
# TSLA
#               open    high       low   close  adjusted_close   volume  \
# date
# 2018-12-11  369.91  372.09  360.2601  366.76          366.76  6287288
#
#             dividend_amount  split_coefficient
# date
# 2018-12-11              0.0                1.0
#             open  high    low  close  adjusted_close    volume  \
# date
# 2010-06-29  19.0  25.0  17.54  23.89           23.89  18766300
#
#             dividend_amount  split_coefficient
# date
# 2010-06-29              0.0                1.0
# ******************************************************************************************************************************************************
# NVDA
#               open      high    low   close  adjusted_close    volume  \
# date
# 2018-12-11  155.56  155.8804  145.0  148.19          148.19  16700499
#
#             dividend_amount  split_coefficient
# date
# 2018-12-11              0.0                1.0
#             open   high    low   close  adjusted_close   volume  \
# date
# 1999-01-22  21.0  23.44  18.63  1.5172          1.5172  5655600
#
#             dividend_amount  split_coefficient
# date
# 1999-01-22              0.0                1.0
# ******************************************************************************************************************************************************
# GE
#             open  high   low  close  adjusted_close     volume  \
# date
# 2018-12-11  7.04  7.13  6.66   6.76            6.76  123806103
#
#             dividend_amount  split_coefficient
# date
# 2018-12-11              0.0                1.0
#              open   high   low    close  adjusted_close   volume  \
# date
# 1998-01-02  73.31  74.06  72.0  13.4795         13.4795  3129100
#
#             dividend_amount  split_coefficient
# date
# 1998-01-02              0.0                1.0
# ******************************************************************************************************************************************************
# FB
#               open      high    low   close  adjusted_close    volume  \
# date
# 2018-12-11  143.88  143.8741  141.1  142.08          142.08  19381607
#
#             dividend_amount  split_coefficient
# date
# 2018-12-11              0.0                1.0
#              open  high   low    close  adjusted_close     volume  \
# date
# 2012-05-18  42.05  45.0  38.0  38.2318         38.2318  573576400
#
#             dividend_amount  split_coefficient
# date
# 2012-05-18              0.0                1.0
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 2) Modifies the DF we made to include new columns
# Creates new columns taylored to our analysis. The columns include; Fluctuation, Volatility, % Term Moving Average, 5, 50 and 200 day Moving Averages.

# %%
#this loops through and modifies each DF for the symbols that we need. 

for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol)
    df= bk.mod_df(df)
    display(df.head(5))
    display(df.tail(1))
    bk.line()
# Out:
# TSLA
#               open    high       low    close  adjusted_close    volume  \
# date
# 2018-12-11  369.91  372.09  360.2601  366.760         366.760   6287288
# 2018-12-10  360.00  365.98  353.1200  365.150         365.150   6574349
# 2018-12-07  369.00  379.49  357.6500  357.965         357.965  11511177
# 2018-12-06  356.01  367.38  350.7600  363.060         363.060   7842508
# 2018-12-04  356.05  368.68  352.0000  359.700         359.700   8461945
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12-11              0.0                1.0     3.225515   3.150
# 2018-12-10              0.0                1.0     3.521840  -5.150
# 2018-12-07              0.0                1.0     6.101155  11.035
# 2018-12-06              0.0                1.0     4.577756  -7.050
# 2018-12-04              0.0                1.0     4.637198  -3.650
#
#             volatility    ma(5)  ma(50)  ma(200)       date       day  \
# date
# 2018-12-11     11.8299      NaN     NaN      NaN 2018-12-11   Tuesday
# 2018-12-10     12.8600      NaN     NaN      NaN 2018-12-10    Monday
# 2018-12-07     21.8400      NaN     NaN      NaN 2018-12-07    Friday
# 2018-12-06     16.6200      NaN     NaN      NaN 2018-12-06  Thursday
# 2018-12-04     16.6800  362.527     NaN      NaN 2018-12-04   Tuesday
#
#                month  year
# date
# 2018-12-11  December  2018
# 2018-12-10  December  2018
# 2018-12-07  December  2018
# 2018-12-06  December  2018
# 2018-12-04  December  2018
#             open  high    low  close  adjusted_close    volume  \
# date
# 2010-06-29  19.0  25.0  17.54  23.89           23.89  18766300
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2010-06-29              0.0                1.0    31.226455   -4.89
#
#             volatility   ma(5)   ma(50)    ma(200)       date      day month  \
# date
# 2010-06-29        7.46  20.998  19.8336  23.726245 2010-06-29  Tuesday  June
#
#             year
# date
# 2010-06-29  2010
# ******************************************************************************************************************************************************
# NVDA
#               open      high      low   close  adjusted_close    volume  \
# date
# 2018-12-11  155.56  155.8804  145.000  148.19          148.19  16700499
# 2018-12-10  145.80  152.8599  145.650  151.86          151.86  15379729
# 2018-12-07  158.46  158.8700  145.616  147.61          147.61  17041949
# 2018-12-06  151.44  158.4920  150.810  158.29          158.29  17307741
# 2018-12-04  168.24  168.4400  156.500  157.11          157.11  20302787
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12-11              0.0                1.0     7.342196    7.37
# 2018-12-10              0.0                1.0     4.747728   -6.06
# 2018-12-07              0.0                1.0     8.979066   10.85
# 2018-12-06              0.0                1.0     4.853118   -6.85
# 2018-12-04              0.0                1.0     7.599771   11.13
#
#             volatility    ma(5)  ma(50)  ma(200)       date       day  \
# date
# 2018-12-11     10.8804      NaN     NaN      NaN 2018-12-11   Tuesday
# 2018-12-10      7.2099      NaN     NaN      NaN 2018-12-10    Monday
# 2018-12-07     13.2540      NaN     NaN      NaN 2018-12-07    Friday
# 2018-12-06      7.6820      NaN     NaN      NaN 2018-12-06  Thursday
# 2018-12-04     11.9400  152.612     NaN      NaN 2018-12-04   Tuesday
#
#                month  year
# date
# 2018-12-11  December  2018
# 2018-12-10  December  2018
# 2018-12-07  December  2018
# 2018-12-06  December  2018
# 2018-12-04  December  2018
#             open   high    low   close  adjusted_close   volume  \
# date
# 1999-01-22  21.0  23.44  18.63  1.5172          1.5172  5655600
#
#             dividend_amount  split_coefficient  fluctuation   oc_var  \
# date
# 1999-01-22              0.0                1.0   317.031374  19.4828
#
#             volatility    ma(5)    ma(50)   ma(200)       date     day  \
# date
# 1999-01-22        4.81  1.56328  1.575806  1.581623 1999-01-22  Friday
#
#               month  year
# date
# 1999-01-22  January  1999
# ******************************************************************************************************************************************************
# GE
#             open  high   low  close  adjusted_close     volume  \
# date
# 2018-12-11  7.04  7.13  6.66   6.76            6.76  123806103
# 2018-12-10  6.97  7.12  6.75   6.93            6.93  112813300
# 2018-12-07  7.30  7.38  6.99   7.01            7.01  114480098
# 2018-12-06  7.20  7.39  7.15   7.35            7.35  112965740
# 2018-12-04  7.75  7.81  7.28   7.28            7.28  133329757
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12-11              0.0                1.0     6.952663    0.28
# 2018-12-10              0.0                1.0     5.339105    0.04
# 2018-12-07              0.0                1.0     5.563481    0.29
# 2018-12-06              0.0                1.0     3.265306   -0.15
# 2018-12-04              0.0                1.0     7.280220    0.47
#
#             volatility  ma(5)  ma(50)  ma(200)       date       day     month  \
# date
# 2018-12-11        0.47    NaN     NaN      NaN 2018-12-11   Tuesday  December
# 2018-12-10        0.37    NaN     NaN      NaN 2018-12-10    Monday  December
# 2018-12-07        0.39    NaN     NaN      NaN 2018-12-07    Friday  December
# 2018-12-06        0.24    NaN     NaN      NaN 2018-12-06  Thursday  December
# 2018-12-04        0.53  7.066     NaN      NaN 2018-12-04   Tuesday  December
#
#             year
# date
# 2018-12-11  2018
# 2018-12-10  2018
# 2018-12-07  2018
# 2018-12-06  2018
# 2018-12-04  2018
#              open   high   low    close  adjusted_close   volume  \
# date
# 1998-01-02  73.31  74.06  72.0  13.4795         13.4795  3129100
#
#             dividend_amount  split_coefficient  fluctuation   oc_var  \
# date
# 1998-01-02              0.0                1.0    15.282466  59.8305
#
#             volatility     ma(5)     ma(50)    ma(200)       date     day  \
# date
# 1998-01-02        2.06  13.58188  13.963344  15.176759 1998-01-02  Friday
#
#               month  year
# date
# 1998-01-02  January  1998
# ******************************************************************************************************************************************************
# FB
#               open      high       low   close  adjusted_close    volume  \
# date
# 2018-12-11  143.88  143.8741  141.1000  142.08          142.08  19381607
# 2018-12-10  139.60  143.0500  139.0100  141.85          141.85  26309166
# 2018-12-07  139.25  140.8700  136.6566  137.42          137.42  21195460
# 2018-12-06  133.82  139.7000  133.6700  139.63          139.63  28218145
# 2018-12-04  140.73  143.3900  137.1600  137.93          137.93  30307400
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12-11              0.0                1.0     1.952492    1.80
# 2018-12-10              0.0                1.0     2.848079   -2.25
# 2018-12-07              0.0                1.0     3.066075    1.83
# 2018-12-06              0.0                1.0     4.318556   -5.81
# 2018-12-04              0.0                1.0     4.516784    2.80
#
#             volatility    ma(5)  ma(50)  ma(200)       date       day  \
# date
# 2018-12-11      2.7741      NaN     NaN      NaN 2018-12-11   Tuesday
# 2018-12-10      4.0400      NaN     NaN      NaN 2018-12-10    Monday
# 2018-12-07      4.2134      NaN     NaN      NaN 2018-12-07    Friday
# 2018-12-06      6.0300      NaN     NaN      NaN 2018-12-06  Thursday
# 2018-12-04      6.2300  139.782     NaN      NaN 2018-12-04   Tuesday
#
#                month  year
# date
# 2018-12-11  December  2018
# 2018-12-10  December  2018
# 2018-12-07  December  2018
# 2018-12-06  December  2018
# 2018-12-04  December  2018
#              open  high   low    close  adjusted_close     volume  \
# date
# 2012-05-18  42.05  45.0  38.0  38.2318         38.2318  573576400
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2012-05-18              0.0                1.0    18.309366  3.8182
#
#             volatility     ma(5)     ma(50)    ma(200)       date     day  \
# date
# 2012-05-18         7.0  33.65836  29.838636  25.669904 2012-05-18  Friday
#
#            month  year
# date
# 2012-05-18   May  2012
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 3) Error Analysis
#
# This section determines the RMSE value for each Moving Average case.

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol)
    bk.predict(df)
    bk.line()
# Out:
# TSLA
# RMSE of MA(5) is:  6.34
# RMSE of MA(50) is:  20.11
# RMSE of MA(200) is:  37.34
#
# ******************************************************************************************************************************************************
# NVDA
# RMSE of MA(5) is:  1.95
# RMSE of MA(50) is:  6.25
# RMSE of MA(200) is:  14.26
#
# ******************************************************************************************************************************************************
# GE
# RMSE of MA(5) is:  0.37
# RMSE of MA(50) is:  1.27
# RMSE of MA(200) is:  2.70
#
# ******************************************************************************************************************************************************
# FB
# RMSE of MA(5) is:  2.27
# RMSE of MA(50) is:  7.21
# RMSE of MA(200) is:  13.23
#
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 4) Todays Summary
# Provides a summary of todays performance for the stock symbols that were entered.

# %%
for symbol in range(0,stock_dfs_length):
    print(symbols[symbol])
    bk.todays_summary(stock_dfs[symbol])
    bk.line()
# Out:
# TSLA
# Todays Opening Price:  $369.91
# Todays Highest Price:  $372.09
# Todays Lowest Price:  $360.26
# Todays Closing Price:  $366.76
# Todays Trading Volume:  6,287,288
# Todays Open/Close Variance:  $3.15
# Todays Volatility:  $11.83
# Todays Price Fluctuation:  3.23%
#
# ******************************************************************************************************************************************************
# NVDA
# Todays Opening Price:  $155.56
# Todays Highest Price:  $155.88
# Todays Lowest Price:  $145.00
# Todays Closing Price:  $148.19
# Todays Trading Volume:  16,700,499
# Todays Open/Close Variance:  $7.37
# Todays Volatility:  $10.88
# Todays Price Fluctuation:  7.34%
#
# ******************************************************************************************************************************************************
# GE
# Todays Opening Price:  $7.04
# Todays Highest Price:  $7.13
# Todays Lowest Price:  $6.66
# Todays Closing Price:  $6.76
# Todays Trading Volume:  123,806,103
# Todays Open/Close Variance:  $0.28
# Todays Volatility:  $0.47
# Todays Price Fluctuation:  6.95%
#
# ******************************************************************************************************************************************************
# FB
# Todays Opening Price:  $143.88
# Todays Highest Price:  $143.87
# Todays Lowest Price:  $141.10
# Todays Closing Price:  $142.08
# Todays Trading Volume:  19,381,607
# Todays Open/Close Variance:  $1.80
# Todays Volatility:  $2.77
# Todays Price Fluctuation:  1.95%
#
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 5) Descriptive Visuals
#
# This section is for showing plots of our data and doing a visual approach. *Add percentage indicators for the fluctuation values* Add titles to the graphs

# %%
#generates various plots to look at for each symbol. 
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol)
    bk.plot_price_vs_month(df, symbol)
    bk.plot_price_vs_day(df, symbol)
    bk.plot_price_vs_time(df, symbol)
    bk.plot_fluc_vs_time(df, symbol)
    bk.plot_volume_vs_volatiltiy(df, symbol)
    bk.line()
# Out:
# TSLA
# Correlation1:  0.7389764373728035
# ******************************************************************************************************************************************************
# NVDA
# Correlation1:  0.00914052400965441
# ******************************************************************************************************************************************************
# GE
# Correlation1:  -0.160155255423403
# ******************************************************************************************************************************************************
# FB
# Correlation1:  0.13825685423838543
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 6) News and Sentiment Analysis
#
# In this section, the news articles are provided as well as the last 30 'tweets' from stock twits. At the end of each line, there is a % value in [] which indicates the sentiment value of the headline/tweet. It is on a continous scale from [-100 : 100] and the value is shown as a % value. 0 is a neutral headline.

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol, 'news','\n')
    bk.news(symbol)
    bk.line()
print('DONE')
# Out:
# AAPL news
#
# 1) Apple: Holiday Gifts[0.0%]
# 2) Cryptoassets Explained: Civic[0.0%]
# 3) Invesco S&P 500 Quality ETF (SPHQ) November Summary[0.0%]
# 4) Supermicro says outside investigator found no evidence of Chinese spy chips, disputing Businessweek[0.0%]
# 5) What Should I Do With My AT&T Shares?[0.0%]
#
#
# ******************************************************************************************************************************************************
# MSFT news
#
# 1) Microsoft: The Market Is Right, This Time[28.6%]
# 2) Portfolio Update: Stocks Getting Slammed As Dividends Shine Bright[70.0%]
# 3) Invesco QQQ ETF (QQQ) November Summary[0.0%]
# 4) M12 and VC partners award $4 million to two women-led companies transforming enterprise tech[0.0%]
# 5) QQQ Rebalancing In A Deteriorating Market[0.0%]
#
#
# ******************************************************************************************************************************************************
# TSLA news
#
# 1) Tesla seeks $167M in lawsuit against former employee[0.0%]
# 2) Tesla is seeking $167 million in damages from the former employee Elon Musk accused of sabotage[0.0%]
# 3) China on track for first drop in auto sales since 1990[25.0%]
# 4) How Long Can Elon Musk Poke Regulators And Tempt Fate? (Podcast)[-5.0%]
# 5) Elon Musk hints at electric pickup unveiling next year[0.0%]
#
#
# ******************************************************************************************************************************************************
# NVDA news
#
# 1) Nvidia -2% on SoftBank stake sale headlines[0.0%]
# 2) Invesco S&P 500 Quality ETF (SPHQ) November Summary[0.0%]
# 3) Why Have Institutions Bought Nvidia And Sold AMD Lately?[-30.0%]
# 4) Portfolio Update: Stocks Getting Slammed As Dividends Shine Bright[70.0%]
# 5) QQQ Rebalancing In A Deteriorating Market[0.0%]
#
#
# ******************************************************************************************************************************************************
# DONE

# %% [markdown]
# ## 7) StockTwits and Sentiment Analysis

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol, 'Stock Twits Feed','\n')
    bk.stock_twits(symbol)
    bk.line()
print('DONE')
# Out:
# AAPL Stock Twits Feed
#
# 1) $AMD what will trump tweet to try and protect the markets tomorrow? $SPY $DJIA $AAPL[0.0%]
# 2) $AAPL What do you expect until the EOD?[0.0%]
# 3) $AAPL it wi drop 4% tomorrow[0.0%]
# 4) [VIDEO] Chart Analysis + Free Trade Ideas $AAPL $AMZN $GOOGL $BABA $NFLX $FB $NVDA $BIDU - click link to watch &gt;&gt; https://www.thetradinganalyst.com/option-trading-strategies-aapl-amzn-googl-baba-by-thetrading/[40.0%]
# 5) $AAPL this is bottoming short term[0.0%]
# 6) Some of todays most active stock options 12.11.18  $GE $BAC $BX $F $AAPL $KO $NBR $SLB[18.3%]
# 7) $AAPL bulls keep dreaming big sell off coming for this stock[0.0%]
# 8) $SPY Once I’m Bull to invest I’m going to ride it like a pro back up long target will be 291. $TVIX $UVXY $VIX $AAPL $TSLA $BABA $JD[-2.5%]
# 9) $AAPL $SPY $QQQ If it breaks below $162 (which should be soon) then WATCH OUT!![0.0%]
# 10) Hot Options Report For End Of Day December 11th - $BAC, $BX, $F, $AAPL, $KO, $NBR
# http://theoptionsinsider.com/hot-options-report-for-end-of-day-december-11th-bac-bx-f-aapl-ko-nbr/[25.0%]
# 11) $SPY $DIA $QQQ $AAPL US Stock Mkt idown -10% despite US Market up 23.3%💰-&gt;Election11/08/2016🤡’sPLENTY to give back due to uncertainty.👎🐻[-6.2%]
# 12) $AAPL Apple Pay Launches in Germany[0.0%]
# 13) $AMD lowest unemployment the history of the US. ya ok -- everyone report him please, they will ban him so fast $AAPL $AMZN $NFLX[35.0%]
# 14) $AAPL very happy with the hold today.  The fight was real![62.5%]
# 15) @4LT3 @EarlEBird @andros28 I cannot begin to explain what a useless profession the analyst is. $AAPL[-50.0%]
# 16) $AAPL I guess we take another shot at breaking 170 tomorrow again.. ugh[0.0%]
# 17) $AAPL $QQQ $162 PT on Apple...soon[0.0%]
# 18) @David_Trentham @EarlEBird @andros28 what about the ahole that gave the last $AAPL upgrade &amp; had the highest price target? That was cool.[17.5%]
# 19) $SPY $NFLX $AAPL $QQQ = Calls    $VXX may = Puts!!!  The risk is unraveling.[0.0%]
# 20) FAANG Stocks Overview: https://techniquant.com/reports/market-reports/faang/2018-12-11/
# $GOOGL +0.80%
# $FB +0.16%
# $AMZN +0.13%
# $AAPL -0.57%
# $NFLX -1.62%[0.0%]
# 21) $AAPL closes within previous day&#39;s range: https://techniquant.com/reports/stock-aapl-daily-technical-analysis-report-for-2018-12-11/[-16.7%]
# 22) $AAPL Just need one more day of this being red. Gotta wait it out before q4 ER[25.0%]
# 23) Here’s what 231 Estimize analysts believe $AAPL will report for Q1 2019 revenue [Reporting 01/29 AMC]
# http://www.estimize.com/intro/aapl?chart=historical&amp;metric_name=revenue&amp;utm_content=AAPL&amp;utm_medium=revenue_update&amp;utm_source=stocktwits[0.0%]
# 24) DEC 11 RECAP
#
# $SFIX $MYOS $MBRX $SN $MDXG $NURO $HIMX $PTX $DEST $VBIV $SEII $NAKD $LLEX $NBEV $OPTT $AAPL $AETI[0.0%]
# 25) $AAPL President Cheeto about to destroy the market. Price Objective 120[-10.0%]
# 26) $AAPL no new good products for many years to come[37.7%]
# 27) $AAPL so I guess I should sell the morning gap up[0.0%]
# 28) $AAPL TC ousted soon[0.0%]
# 29) $AMD PSA 🚨 🚨 WE aren&#39;t in a bear market, just a SIMPLE 25-50% retrace / time $AAPL $AMZN $FB $NFLX $NVDA[0.0%]
# 30) US MARKET | MOST ACTIVES  $GE $AMD $BAC $CHK $NOK $AAPL $T $MSFT $F $LYG http://tinyurl.com/yd4pxf2w[50.0%]
#
#
# Total Sentiment Score: 7.5
# ******************************************************************************************************************************************************
# MSFT Stock Twits Feed
#
# 1) @realheisenberg Except it always works over the long-term. Some will roll-over and die, others are the next $AMZN or $MSFT. They pay off.[0.0%]
# 2) $MSFT when i call it goes down and when i put it goes up and when i have both it stalls and the moment i sell the call, it goes up!!!!![-47.5%]
# 3) $MSFT breaks back above 50-day moving average: https://techniquant.com/reports/stock-msft-daily-technical-analysis-report-for-2018-12-11/[-5.0%]
# 4) Here’s what 121 Estimize analysts believe $MSFT will report for Q2 2019 revenue [Reporting 01/30 AMC]
# http://www.estimize.com/intro/msft?chart=historical&amp;metric_name=revenue&amp;utm_content=MSFT&amp;utm_medium=revenue_update&amp;utm_source=stocktwits[0.0%]
# 5) US MARKET | MOST ACTIVES  $GE $AMD $BAC $CHK $NOK $AAPL $T $MSFT $F $LYG http://tinyurl.com/yd4pxf2w[50.0%]
# 6) $MSFT let’s test 107.5 at open tomorrow.[0.0%]
# 7) $MSFT $SPY can we open red and then go green tomorrow id like to close my puts 😅[-6.7%]
# 8) $MSFT get ready for 2 - 3 % Drop tomorrow[20.0%]
# 9) $MSFT shooting up?[0.0%]
# 10) $MSFT good until this breaking news from Trump. Poo. Possibly closing the government down for boarder security.[18.1%]
# 11) $MSFT  buy puts... Last chance... Dont miss opportunity[0.0%]
# 12) $SPY $AAPL $MSFT $QQQ dump into close 😤[0.0%]
# 13) Another leg down coming.Take profits $AAPL $NFLX $BABA $PYPL $GOOG $NVDA $JNJ $MU $TWLO $QQQ $MSFT $MA $V $AMD $SPY $SQ $AMZN $INTC $UNH $FB[-15.6%]
# 14) $SPY $DIS and $MSFT have been surprisingly resilient this year.[70.0%]
# 15) $MSFT short squeeze on steroids 💪[0.0%]
# 16) $MSFT  I don&#39;t know why, but I have the feeling that something dramatic is about to happen. . .[-43.3%]
# 17) $MSFT closes above $109.50 for a breakout above the VWAP 🐂[0.0%]
# 18) $MSFT bear trap executed 😭[0.0%]
# 19) $MSFT always strong 🐉🔥[43.3%]
# 20) $MSFT I need huge miracle keep going higher
#
# Thanks[28.3%]
# 21) $MSFT $SPY Bears hate him! See how he saved the S&amp;P from dropping into a bear market in one simple trick! Learn the truth NOW![-50.0%]
# 22) $MSFT in case you missed it first time[25.0%]
# 23) $MSFT Hard to believe it is bigger than $AAPL and $AMZN now. Eventually I think $AMZN will be way bigger than $AAPL and $MSFT[-9.7%]
# 24) $MSFT[0.0%]
# 25) $MSFT had a P/E of only 10 in the period of 2010-2012, compared to 44 today[0.0%]
# 26) $MSFT Buy winners like MSFT and stash them away for life.[0.0%]
# 27) $AMZN $AAPL $MSFT $GOOG $SPY CNBC reporting Trump is about to &quot;condemn the shit out of China&quot;[-20.0%]
# 28) $MSFT Man, I&#39;ve been getting paid in this name for so long I just can&#39;t let it go[-5.0%]
# 29) $MSFT There is a new sheriff in town, and his name us Mr. Softee[13.6%]
# 30) $AAPL $amzn $googl $msft market complete dominated by machines. Might as well get skynet to trade for you.[10.0%]
#
#
# Total Sentiment Score: 2.5
# ******************************************************************************************************************************************************
# TSLA Stock Twits Feed
#
# 1) $TSLA finds buyers at key support level: https://techniquant.com/reports/stock-tsla-daily-technical-analysis-report-for-2018-12-11/[0.0%]
# 2) $SPY Once I’m Bull to invest I’m going to ride it like a pro back up long target will be 291. $TVIX $UVXY $VIX $AAPL $TSLA $BABA $JD[-2.5%]
# 3) $TSLA Tough Call here @ a triple top. Possible pullback then a run to higher levels ???[9.0%]
# 4) $TSLA $SPY jefferies predicts 45% short squeeze to the upside if Tesla breaks these levels. At the mean time $JPM sitting at $180 target 😂[-15.6%]
# 5) $TSLA  remember Martin Tripp?   He was the bear savior... about five saviors ago[0.0%]
# 6) $TSLA Tesla Patents Google Glass-like Augmented Reality System for Factory Workers[0.0%]
# 7) $TSLA Elon Musk Tweets Tesla Store to Probably Open in South Africa by End of Next Year[0.0%]
# 8) $TSLA MUSK GIVES AN INCOHERENT  RETARDO INTERVIEW ON MINUTES ..AND PEOPLE BUY THE STOCK!    HILARIOUS!#DONT-BE-A-MUSK-CHEERLEADER[-25.0%]
# 9) $TSLA we got robbed by softbank reporting of selling stake in nvda. We will resume this tomorrow. GL[0.0%]
# 10) $TSLA analysts on Estimize are expecting 178.06% YoY EPS growth for Q4, down from 199.32% in Q3 [Reporting 02/06 AMC]
# http://www.estimize.com/intro/tsla?chart=historical&amp;metric_name=eps&amp;utm_content=TSLA&amp;utm_medium=eps_growth&amp;utm_source=stocktwits[-15.6%]
# 11) $TSLA manipulation to kill call and puts premiums this week[0.0%]
# 12) $TSLA I&#39;m not sure it&#39;s worth trading anymore. There are 10 news headlines a day that make the market react up and down. Tough deal.[-12.4%]
# 13) @HiDrNick oh the dumpster pumper from $TLRY is at $TSLA now.[0.0%]
# 14) $TSLA more pedos in here than Baby Gap[50.0%]
# 15) $TSLA Holy shit what is ELCR (electric car company inc) in MO?  Moved 9,900% today and Im bullish for years on TSLA.  Someone know?[-20.0%]
# 16) $TSLA 1ST TARGET FOR TMOROW IS 360. LOTS OF BULLTARDS IN HERE BETTING FOR A &gt;350 CLOSE THIS WEEK AND NEXT WEEK EXP. CLUELESS NEWBIES LOL[40.0%]
# 17) $TSLA
# Tesla is suing alleged ‘saboteur’ for $167 million  https://techcrunch.com/2018/12/11/tesla-is-suing-alleged-saboteur-for-167-million/[-10.0%]
# 18) $TSLA omg, i said 366 yesterday. today it closed at 366.6.  666 with a three - yikes in numerological speak shorts. Week&#39;s end price will be[-10.0%]
# 19) $TSLA  highest close since August 8[0.0%]
# 20) $TSLA so close.  You get an animal sticker for the effort though.[0.0%]
# 21) $TSLA oh my, someone bought 46K on the close[0.0%]
# 22) $BNFT Strongest stock in the entire market along with $TSLA.  Heavy bidders all day.[-10.0%]
# 23) $TSLA well, well...[0.0%]
# 24) $TSLA Who needed gainz today. &#39;Tis the season of giving.[0.0%]
# 25) $AMZN ~45pts thru open low. ~30pts bounce w/ SPY.
# $TSLA $NVDA $NFLX $AAPL Clean range today.[12.2%]
# 26) $TSLA this is the week to make a little money[-18.8%]
# 27) $TSLA Bulls quiet asf right now though.[14.3%]
# 28) $TSLA oh, that channel is working to pull it back in. A close above $366 would be impressive.[33.3%]
# 29) $TSLA I wuuz short the whole day- 370, 366 etc.[10.0%]
# 30) $TSLA sell[0.0%]
#
#
# Total Sentiment Score: 1.0
# ******************************************************************************************************************************************************
# NVDA Stock Twits Feed
#
# 1) $NVDA  &quot;SoftBank may decide against exercising its option to sell its stake if Nvidia’s share price rallies, the people said.&quot;
# added more[50.0%]
# 2) $NVDA - You think institutions want to be holding this when softbank starts selling? My TP just changed to $100.[0.0%]
# 3) [VIDEO] Chart Analysis + Free Trade Ideas $AAPL $AMZN $GOOGL $BABA $NFLX $FB $NVDA $BIDU - click link to watch &gt;&gt; https://www.thetradinganalyst.com/option-trading-strategies-aapl-amzn-googl-baba-by-thetrading/[40.0%]
# 4) $NVDA $150 tmrw[0.0%]
# 5) $NVDA 145 test tomorrow? Then 140 to end the week?[0.0%]
# 6) $NVDA Strong buy[43.3%]
# 7) $NVDA Freefall mode into next week...[0.0%]
# 8) $NVDA- Trading Question: When largest stakeholders announces co. is hurting &amp; they want out, it&#39;s time to  A) buy much as possible B) short[0.0%]
# 9) $NVDA fucking softbank is day trading this shit 😂[-40.0%]
# 10) $NVDA grabbed some 145 12/21 puts at close at 4.4 . Weak right now, expecting it to bleed a little more[5.6%]
# 11) $NVDA finds buyers around 145.00 for the third day in a row: https://techniquant.com/reports/stock-nvda-daily-technical-analysis-report-for-2018-12-11/[0.0%]
# 12) Estimize revenue expectations are 8.03% higher than that of Wall Street for $NVDA Q4 [Reporting 02/07 AMC]
# http://www.estimize.com/intro/nvda?chart=change-over-time&amp;metric_name=revenue&amp;utm_content=NVDA&amp;utm_medium=revenue_difference&amp;utm_source=stocktwits[25.0%]
# 13) $NVDA today... big $ knew ahead of time today. we r minnows swimming with sharks. stay close to rocks. :- )[25.0%]
# 14) $NVDA SoftBank just put a collar on... Sold OTM calls against it&#39;s equity stake to finance OTM put hedge. Not sure on the strikes....[-25.0%]
# 15) $NVDA time to get in?[0.0%]
# 16) $AMD PSA 🚨 🚨 WE aren&#39;t in a bear market, just a SIMPLE 25-50% retrace / time $AAPL $AMZN $FB $NFLX $NVDA[0.0%]
# 17) $NVDA - think this will get killed tomorrow with Softbank selling news. Take positions now in advance.[-20.0%]
# 18) $NVDA[0.0%]
# 19) $NVDA Softbank doesn&#39;t give a shit about announcing it.  You should thank them.  They can sell at $240 unlike retail.[-20.0%]
# 20) $NVDA price is actually higher now then before Softbank announced they are selling, so bought puts &amp; will short AHs.[12.5%]
# 21) @packleader they already have a contract option to sell @ 240 avg price $NVDA[0.0%]
# 22) $NVDA stock was lower before news … softbank is just an excuse[-5.0%]
# 23) $NVDA &quot;f$@* that. Mut$#!*% (Navidia) dead[-20.0%]
# 24) $NVDA i think this is bs. Nobody tells people before selling.[0.0%]
# 25) $NVDA SoftBank news is bogus imo. if they’re planning to unload why leak it as it would lead to sp declining which is not in their interests[0.0%]
# 26) $NVDA only thing that will save this is a takeover. Intel buys them for 225[0.0%]
# 27) $NVDA why is it holding up[0.0%]
# 28) $NVDA  &quot;Bloomberg reports that no final decision has been made and SoftBank could decide to keep its stake or only sell a portion. &quot;[0.0%]
# 29) $NVDA did people not read the article?  there&#39;s literally no obligation from SoftBank to do anything.[0.0%]
# 30) $NVDA  they&#39;ll change their minds if the stock goes above their $230-$240 negotiated / protected price[0.0%]
#
#
# Total Sentiment Score: 2.4
# ******************************************************************************************************************************************************
# DONE
