# %%
#Initial Imports
import back_end as bk

# %%
#symbol = input("Enter a stock symbol: ").upper()
#bk.alphaVantageJSON(symbol)
symbol = 'AMZN'
bk.test(symbol)
df_user = bk.make_df(symbol)
display(df_user.head())
# Out:
# <h1>df_user.head()</h1>

# %%
bk.show_data(df_user)
