# %% [markdown]
# ## Stock Analysis Dashboard

# %%
#Initial Imports
import back_end as bk
from IPython.display import HTML, display

# %% [markdown]
# ## Please Enter a Symbol
# This block is used to get the stock symbol from the user and then generates a Pandas Df from the data. It then displays the head so we know it worked succesfully

# %%
#symbol = input("Enter a stock symbol: ").upper()
#symbol = 'AMZN' *
#bk.pass_symbol(symbol)
#df_user = bk.make_df(symbol) *
#display(df_user.head())*
symbols = bk.get_stocks() #this currently works to pass a repetaed list of inputs that the user will get 
stock_dfs = bk.make_df2(symbols)
stock_dfs_length = len(stock_dfs)
for symbol in range(0,stock_dfs_length):
    print(symbols[symbol])
    display(stock_dfs[symbol].head(1))
# Out:
# Enter a stock symbol:  amzn
# Enter a stock symbol:  aapl
# Enter a stock symbol:  msft
# Enter a stock symbol:  baba
# AMZN
#                open     high      low    close  adjusted_close   volume  \
# date
# 2018-12-07  1705.07  1718.93  1625.46  1629.13         1629.13  7576132
#
#             dividend_amount  split_coefficient
# date
# 2018-12-07              0.0                1.0
# AAPL
#               open    high    low   close  adjusted_close    volume  \
# date
# 2018-12-07  173.49  174.49  168.3  168.49          168.49  42281631
#
#             dividend_amount  split_coefficient
# date
# 2018-12-07              0.0                1.0
# MSFT
#               open    high    low   close  adjusted_close    volume  \
# date
# 2018-12-07  108.38  109.45  104.3  104.82          104.82  45044937
#
#             dividend_amount  split_coefficient
# date
# 2018-12-07              0.0                1.0
# BABA
#              open    high     low   close  adjusted_close    volume  \
# date
# 2018-12-07  155.4  158.05  151.73  153.06          153.06  17447930
#
#             dividend_amount  split_coefficient
# date
# 2018-12-07              0.0                1.0

# %% [markdown]
# ## Modifies the DF we made to include new columns
# Makes new columns for our analysis. Includes flucuation.

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol)
    df= bk.mod_df(df)
    bk.plot_price_vs_month(df, symbol)
    display(df.head(10))
# Out:
# AMZN
# RMSE of MA(5) is:  9.70
# RMSE of MA(50) is:  33.70
# RMSE of MA(200) is:  80.24
#                open     high      low    close  adjusted_close   volume  \
# date
# 2018-12-07  1705.07  1718.93  1625.46  1629.13         1629.13  7576132
# 2018-12-06  1614.87  1701.05  1609.85  1699.19         1699.19  8789394
# 2018-12-04  1756.00  1770.34  1665.00  1668.40         1668.40  8694455
# 2018-12-03  1769.46  1778.34  1730.00  1772.36         1772.36  6862160
# 2018-11-30  1679.50  1696.00  1666.50  1690.17         1690.17  5761761
# 2018-11-29  1674.99  1689.99  1652.33  1673.57         1673.57  6613243
# 2018-11-28  1613.92  1681.45  1601.21  1677.75         1677.75  8458738
# 2018-11-27  1575.99  1597.65  1558.01  1581.42         1581.42  5783227
# 2018-11-26  1539.00  1584.81  1524.22  1581.33         1581.33  6257716
# 2018-11-23  1517.00  1536.20  1501.81  1502.06         1502.06  2707642
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12
# date
# 2018-12-07      6.1900      NaN     NaN      NaN 2018-12-07     Friday
# 2018-12-06      4.3600      NaN     NaN      NaN 2018-12-06   Thursday
# 2018-12-04      6.1199      NaN     NaN      NaN 2018-12-04    Tuesday
# 2018-12-03      3.7300      NaN     NaN      NaN 2018-12-03     Monday
# 2018-11-30      3.3000  176.660     NaN      NaN 2018-11-30     Friday
# 2018-11-29      5.1000  178.872     NaN      NaN 2018-11-29   Thursday
# 2018-11-28      6.3600  180.116     NaN      NaN 2018-11-28  Wednesday
# 2018-11-27      3.8900  179.626     NaN      NaN 2018-11-27    Tuesday
# 2018-11-26      4.6900  177.586     NaN      NaN 2018-11-26     Monday
# 2018-11-23      4.4950  176.328     NaN      NaN 2018-11-23     Friday
#
#                month  year
# date
# 2018-12-07  December  2018
# 2018-12-06  December  2018
# 2018-12-04  December  2018
# 2018-12-03  December  2018
# 2018-11-30  November  2018
# 2018-11-29  November  2018
# 2018-11-28  November  2018
# 2018-11-27  November  2018
# 2018-11-26  November  2018
# 2018-11-23  November  2018
# MSFT
# RMSE of MA(5) is:  0.62
# RMSE of MA(50) is:  2.00
# RMSE of MA(200) is:  4.37
#               open      high       low   close  adjusted_close    volume  \
# date
# 2018-12-07  108.38  109.4500  104.3000  104.82          104.82  45044937
# 2018-12-06  105.82  109.2400  105.0000  109.19          109.19  49107431
# 2018-12-04  111.94  112.6373  108.2115  108.52          108.52  45196984
# 2018-12-03  113.00  113.4200  110.7300  112.09          112.09  34732772
# 2018-11-30  110.70  110.9700  109.3600  110.89          110.89  33665624
# 2018-11-29  110.33  111.1150  109.0300  110.19          110.19  28123195
# 2018-11-28  107.89  111.3300  107.8600  111.12          111.12  46788461
# 2018-11-27  106.27  107.3300  105.3600  107.14          107.14  29124486
# 2018-11-26  104.79  106.6300  104.5800  106.47          106.47  32336165
# 2018-11-23  102.17  103.8099  102.0000  103.07          103.07  13823099
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12-07              0.0                1.0     4.913185    3.56
# 2018-12-06              0.0                1.0     3.883139   -3.37
# 2018-12-04              0.0                1.0     4.078327    3.42
# 2018-12-03              0.0                1.0     2.399857    0.91
# 2018-11-30              0.0                1.0     1.451889   -0.19
# 2018-11-29              0.0                1.0     1.892186    0.14
# 2018-11-28              0.0                1.0     3.122750   -3.23
# 2018-11-27              0.0                1.0     1.838716   -0.87
# 2018-11-26              0.0                1.0     1.925425   -1.68
# 2018-11-23              0.0                1.0     1.755991   -0.90
#
#             volatility    ma(5)  ma(50)  ma(200)       date        dow  \
# date
# 2018-12-07      5.1500      NaN     NaN      NaN 2018-12-07     Friday
# 2018-12-06      4.2400      NaN     NaN      NaN 2018-12-06   Thursday
# 2018-12-04      4.4258      NaN     NaN      NaN 2018-12-04    Tuesday
# 2018-12-03      2.6900      NaN     NaN      NaN 2018-12-03     Monday
# 2018-11-30      1.6100  109.102     NaN      NaN 2018-11-30     Friday
# 2018-11-29      2.0850  110.176     NaN      NaN 2018-11-29   Thursday
# 2018-11-28      3.4700  110.562     NaN      NaN 2018-11-28  Wednesday
# 2018-11-27      1.9700  110.286     NaN      NaN 2018-11-27    Tuesday
# 2018-11-26      2.0500  109.162     NaN      NaN 2018-11-26     Monday
# 2018-11-23      1.8099  107.598     NaN      NaN 2018-11-23     Friday
#
#                month  year
# date
# 2018-12-07  December  2018
# 2018-12-06  December  2018
# 2018-12-04  December  2018
# 2018-12-03  December  2018
# 2018-11-30  November  2018
# 2018-11-29  November  2018
# 2018-11-28  November  2018
# 2018-11-27  November  2018
# 2018-11-26  November  2018
# 2018-11-23  November  2018
# BABA
# RMSE of MA(5) is:  2.83
# RMSE of MA(50) is:  10.01
# RMSE of MA(200) is:  21.78
#               open    high       low   close  adjusted_close    volume  \
# date
# 2018-12-07  155.40  158.05  151.7300  153.06          153.06  17447930
# 2018-12-06  153.00  155.87  150.5100  155.83          155.83  25335464
# 2018-12-04  164.88  164.98  156.4600  158.34          158.34  22198642
# 2018-12-03  168.64  168.80  163.5100  163.74          163.74  31078508
# 2018-11-30  157.90  160.86  156.7201  160.86          160.86  35071161
# 2018-11-29  158.08  159.00  153.5400  156.28          156.28  20532236
# 2018-11-28  159.01  159.80  155.2600  159.34          159.34  20767058
# 2018-11-27  154.64  157.94  153.5802  156.46          156.46  17911799
# 2018-11-26  153.21  156.53  152.3700  156.01          156.01  16152683
# 2018-11-23  147.30  151.17  147.0000  150.33          150.33   7437479
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12-07              0.0                1.0     4.129100    2.34
# 2018-12-06              0.0                1.0     3.439646   -2.83
# 2018-12-04              0.0                1.0     5.380826    6.54
# 2018-12-03              0.0                1.0     3.230732    4.90
# 2018-11-30              0.0                1.0     2.573604   -2.96
# 2018-11-29              0.0                1.0     3.493729    1.80
# 2018-11-28              0.0                1.0     2.849253   -0.33
# 2018-11-27              0.0                1.0     2.786527   -1.82
# 2018-11-26              0.0                1.0     2.666496   -2.80
# 2018-11-23              0.0                1.0     2.773897   -3.03
#
#             volatility    ma(5)  ma(50)  ma(200)       date        dow  \
# date
# 2018-12-07      6.3200      NaN     NaN      NaN 2018-12-07     Friday
# 2018-12-06      5.3600      NaN     NaN      NaN 2018-12-06   Thursday
# 2018-12-04      8.5200      NaN     NaN      NaN 2018-12-04    Tuesday
# 2018-12-03      5.2900      NaN     NaN      NaN 2018-12-03     Monday
# 2018-11-30      4.1399  158.366     NaN      NaN 2018-11-30     Friday
# 2018-11-29      5.4600  159.010     NaN      NaN 2018-11-29   Thursday
# 2018-11-28      4.5400  159.712     NaN      NaN 2018-11-28  Wednesday
# 2018-11-27      4.3598  159.336     NaN      NaN 2018-11-27    Tuesday
# 2018-11-26      4.1600  157.790     NaN      NaN 2018-11-26     Monday
# 2018-11-23      4.1700  155.684     NaN      NaN 2018-11-23     Friday
#
#                month  year
# date
# 2018-12-07  December  2018
# 2018-12-06  December  2018
# 2018-12-04  December  2018
# 2018-12-03  December  2018
# 2018-11-30  November  2018
# 2018-11-29  November  2018
# 2018-11-28  November  2018
# 2018-11-27  November  2018
# 2018-11-26  November  2018
# 2018-11-23  November  2018

# %% [markdown]
# ## Todays Summary
# Provides a summary of todays performance

# %%
for symbol in range(0,stock_dfs_length):
    print(symbols[symbol])
    bk.todays_summary(stock_dfs[symbol]) #add the other variables to this summary in the abo
# Out:
# AMZN
# Todays Opening Price:  $1,705.07
# Todays Highest Price:  $1,718.93
# Todays Lowest Price:  $1,625.46
# Todays Closing Price:  $1,629.13
# Todays Trading Volume:  7,576,132
# Todays Price Fluctuation:  5.74%
#
# AAPL
# Todays Opening Price:  $173.49
# Todays Highest Price:  $174.49
# Todays Lowest Price:  $168.30
# Todays Closing Price:  $168.49
# Todays Trading Volume:  42,281,631
# Todays Price Fluctuation:  3.67%
#
# MSFT
# Todays Opening Price:  $108.38
# Todays Highest Price:  $109.45
# Todays Lowest Price:  $104.30
# Todays Closing Price:  $104.82
# Todays Trading Volume:  45,044,937
# Todays Price Fluctuation:  4.91%
#
# BABA
# Todays Opening Price:  $155.40
# Todays Highest Price:  $158.05
# Todays Lowest Price:  $151.73
# Todays Closing Price:  $153.06
# Todays Trading Volume:  17,447,930
# Todays Price Fluctuation:  4.13%

# %% [markdown]
# ## Plots and Things
#
# This section is for showing plots of our data and doing a visual approach. *************Add percentage indicatoras for the fluctuation values

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol)
    bk.plot_price_vs_time(df, symbol)
    bk.plot_fluc_vs_time(df, symbol)
    bk.plot_volume_vs_volatiltiy(df, symbol)
# Out:
# AMZN
# Correlation:  -0.007600698687379991
# AAPL
# Correlation:  0.18974116520468123
# MSFT
# Correlation:  -0.19984387853469046
# BABA
# Correlation:  0.5009815879486776

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol, 'news','\n')
    bk.news(symbol)
print('DONE')
    #REMEBER TO ENCODE THE LINKS
# Out:
# AMZN news
#
# 1) This patient's medical record said she'd given birth twice - in fact, she'd never been pregnant[16.7%]
# 2) Actor Edward Norton is trying to change how the TV industry measures viewership[0.0%]
# 3) Wall Street is expecting a two-year pause in big media and telecom deals after a crazy 2018[-30.0%]
# 4) Has The Market Been deFANGed?[0.0%]
# 5) 2018's Most Innovative Firm[26.7%]
#
#
# DONE
# AAPL news
#
# 1) This patient's medical record said she'd given birth twice - in fact, she'd never been pregnant[16.7%]
# 2) Apple Nearing Important Point[40.0%]
# 3) Don't You Dare Trade Options Until You Read This[0.0%]
#
#
# DONE
# MSFT news
#
# 1) Tencent Music, Starbucks And Under Armour In Focus (Stocks To Watch Podcast)[0.0%]
#
#
# DONE
# BABA news
#
# 1) JD's B2B Sales Strength To Keep Revenue Growing[0.0%]
#
#
# DONE
