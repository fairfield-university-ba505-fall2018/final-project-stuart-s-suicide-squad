# %% [markdown]
# # Stock Analysis Dashboard
# Brought to you by: Brian Walsh, Thomas Moroski and Stuart Weinstein
#
# Our goal was to develop an interactive dashboard where users can get descriptive statistics on any US stock.

# %%
#Initial Imports
import back_end as bk

# %% [markdown]
# ## 1) Please Enter a Symbol
# This block is used to get the stock symbol from the user and then generates a Pandas Df from the data. It then displays the head so we know it worked succesfully

# %%
#This block will loop through and ask the user for stock symbols they want to analyze. 'get_stocks' will promt the user for the symbols and return a list of them.
#'make_df' will make the dataframes based on the symbols, and return a list of dataframes. The for loop will simply print the first row of each DF so that we can confirm it worked.

symbols = bk.get_stocks() 
stock_dfs = bk.make_df(symbols)
stock_dfs_length = len(stock_dfs)
for symbol in range(0,stock_dfs_length):
    print(symbols[symbol])
    display(stock_dfs[symbol].head(1))
    display(stock_dfs[symbol].tail(1))
    bk.line()
# Out:
# Enter a stock symbol:  aapl
# Enter a stock symbol:  fb
# Enter a stock symbol:  no
# AAPL
#               open    high    low   close  adjusted_close    volume  \
# date
# 2018-12-11  171.66  171.77  167.0  168.63          168.63  45739669
#
#             dividend_amount  split_coefficient
# date
# 2018-12-11              0.0                1.0
#              open   high   low   close  adjusted_close   volume  \
# date
# 1998-01-02  13.63  16.25  13.5  0.5125          0.5125  6411700
#
#             dividend_amount  split_coefficient
# date
# 1998-01-02              0.0                1.0
# ******************************************************************************************************************************************************
# FB
#               open      high    low   close  adjusted_close    volume  \
# date
# 2018-12-11  143.88  143.8741  141.1  142.08          142.08  19340689
#
#             dividend_amount  split_coefficient
# date
# 2018-12-11              0.0                1.0
#              open  high   low    close  adjusted_close     volume  \
# date
# 2012-05-18  42.05  45.0  38.0  38.2318         38.2318  573576400
#
#             dividend_amount  split_coefficient
# date
# 2012-05-18              0.0                1.0
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 2) Modifies the DF we made to include new columns
# Creates new columns taylored to our analysis. The columns include; Fluctuation, Volatility, % Term Moving Average, 5, 50 and 200 day Moving Averages.

# %%
#this loops through and modifies each DF for the symbols that we need. 

for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol)
    df= bk.mod_df(df)
    display(df.head(5))
    display(df.tail(1))
    bk.line()
# Out:
# AAPL
#               open      high     low   close  adjusted_close    volume  \
# date
# 2018-12-11  171.66  171.7700  167.00  168.63          168.63  45739669
# 2018-12-10  165.00  170.0900  163.33  169.60          169.60  61755952
# 2018-12-07  173.49  174.4900  168.30  168.49          168.49  42281631
# 2018-12-06  171.76  174.7800  170.42  174.72          174.72  43098410
# 2018-12-04  180.95  182.3899  176.27  176.69          176.69  41344282
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12-11              0.0                1.0     2.828678    3.03
# 2018-12-10              0.0                1.0     3.985849   -4.60
# 2018-12-07              0.0                1.0     3.673809    5.00
# 2018-12-06              0.0                1.0     2.495421   -2.96
# 2018-12-04              0.0                1.0     3.463637    4.26
#
#             volatility    ma(5)  ma(50)  ma(200)       date       dow  \
# date
# 2018-12-11      4.7700      NaN     NaN      NaN 2018-12-11   Tuesday
# 2018-12-10      6.7600      NaN     NaN      NaN 2018-12-10    Monday
# 2018-12-07      6.1900      NaN     NaN      NaN 2018-12-07    Friday
# 2018-12-06      4.3600      NaN     NaN      NaN 2018-12-06  Thursday
# 2018-12-04      6.1199  171.626     NaN      NaN 2018-12-04   Tuesday
#
#                month  year
# date
# 2018-12-11  December  2018
# 2018-12-10  December  2018
# 2018-12-07  December  2018
# 2018-12-06  December  2018
# 2018-12-04  December  2018
#              open   high   low   close  adjusted_close   volume  \
# date
# 1998-01-02  13.63  16.25  13.5  0.5125          0.5125  6411700
#
#             dividend_amount  split_coefficient  fluctuation   oc_var  \
# date
# 1998-01-02              0.0                1.0   536.585366  13.1175
#
#             volatility    ma(5)    ma(50)   ma(200)       date     dow  \
# date
# 1998-01-02        2.75  0.54728  0.646218  0.920482 1998-01-02  Friday
#
#               month  year
# date
# 1998-01-02  January  1998
# ******************************************************************************************************************************************************
# FB
#               open      high       low   close  adjusted_close    volume  \
# date
# 2018-12-11  143.88  143.8741  141.1000  142.08          142.08  19340689
# 2018-12-10  139.60  143.0500  139.0100  141.85          141.85  26309166
# 2018-12-07  139.25  140.8700  136.6566  137.42          137.42  21195460
# 2018-12-06  133.82  139.7000  133.6700  139.63          139.63  28218145
# 2018-12-04  140.73  143.3900  137.1600  137.93          137.93  30307400
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2018-12-11              0.0                1.0     1.952492    1.80
# 2018-12-10              0.0                1.0     2.848079   -2.25
# 2018-12-07              0.0                1.0     3.066075    1.83
# 2018-12-06              0.0                1.0     4.318556   -5.81
# 2018-12-04              0.0                1.0     4.516784    2.80
#
#             volatility    ma(5)  ma(50)  ma(200)       date       dow  \
# date
# 2018-12-11      2.7741      NaN     NaN      NaN 2018-12-11   Tuesday
# 2018-12-10      4.0400      NaN     NaN      NaN 2018-12-10    Monday
# 2018-12-07      4.2134      NaN     NaN      NaN 2018-12-07    Friday
# 2018-12-06      6.0300      NaN     NaN      NaN 2018-12-06  Thursday
# 2018-12-04      6.2300  139.782     NaN      NaN 2018-12-04   Tuesday
#
#                month  year
# date
# 2018-12-11  December  2018
# 2018-12-10  December  2018
# 2018-12-07  December  2018
# 2018-12-06  December  2018
# 2018-12-04  December  2018
#              open  high   low    close  adjusted_close     volume  \
# date
# 2012-05-18  42.05  45.0  38.0  38.2318         38.2318  573576400
#
#             dividend_amount  split_coefficient  fluctuation  oc_var  \
# date
# 2012-05-18              0.0                1.0    18.309366  3.8182
#
#             volatility     ma(5)     ma(50)    ma(200)       date     dow  \
# date
# 2012-05-18         7.0  33.65836  29.838636  25.669904 2012-05-18  Friday
#
#            month  year
# date
# 2012-05-18   May  2012
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 3) Error Analysis
#
# This section determines the RMSE value for each Moving Average case.

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol)
    bk.predict(df)
    bk.line()
# Out:
# AAPL
# RMSE of MA(5) is:  1.19
# RMSE of MA(50) is:  4.17
# RMSE of MA(200) is:  8.91
#
# ******************************************************************************************************************************************************
# FB
# RMSE of MA(5) is:  2.27
# RMSE of MA(50) is:  7.21
# RMSE of MA(200) is:  13.23
#
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 4) Todays Summary
# Provides a summary of todays performance for the stock symbols that were entered.

# %%
for symbol in range(0,stock_dfs_length):
    print(symbols[symbol])
    bk.todays_summary(stock_dfs[symbol])
    bk.line()
# Out:
# AAPL
# Todays Opening Price:  $171.66
# Todays Highest Price:  $171.77
# Todays Lowest Price:  $167.00
# Todays Closing Price:  $168.63
# Todays Trading Volume:  45,739,669
# Todays Open/Close Variance:  $3.03
# Todays Volatility:  4.77
# Todays Price Fluctuation:  $2.83%
#
# ******************************************************************************************************************************************************
# FB
# Todays Opening Price:  $143.88
# Todays Highest Price:  $143.87
# Todays Lowest Price:  $141.10
# Todays Closing Price:  $142.08
# Todays Trading Volume:  19,340,689
# Todays Open/Close Variance:  $1.80
# Todays Volatility:  2.77
# Todays Price Fluctuation:  $1.95%
#
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 5) Descriptive Visuals
#
# This section is for showing plots of our data and doing a visual approach. *Add percentage indicators for the fluctuation values* Add titles to the graphs

# %%
#generates various plots to look at for each symbol. 
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol)
    bk.plot_price_vs_month(df, symbol)
    bk.plot_price_vs_day(df, symbol)
    bk.plot_price_vs_time(df, symbol)
    bk.plot_fluc_vs_time(df, symbol)
    bk.plot_volume_vs_volatiltiy(df, symbol)
    bk.line()
# Out:
# AAPL
# Correlation1:  0.19000108365478963
# ******************************************************************************************************************************************************
# FB
# Correlation1:  0.13825646213082562
# ******************************************************************************************************************************************************

# %% [markdown]
# ## 6) News and Sentiment Analysis
#
# In this section, the news articles are provided as well as the last 30 'tweets' from stock twits. At the end of each line, there is a % value in [] which indicates the sentiment value of the headline/tweet. It is on a continous scale from [-100 : 100] and the value is shown as a % value. 0 is a neutral headline.

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol, 'news','\n')
    bk.news(symbol)
    bk.line()
print('DONE')
# Out:
# AAPL news
#
# 1) Apple: Holiday Gifts[0.0%]
# 2) Cryptoassets Explained: Civic[0.0%]
# 3) Invesco S&P 500 Quality ETF (SPHQ) November Summary[0.0%]
# 4) Supermicro says outside investigator found no evidence of Chinese spy chips, disputing Businessweek[0.0%]
# 5) What Should I Do With My AT&T Shares?[0.0%]
#
#
# ******************************************************************************************************************************************************
# FB news
#
# 1) It's Darkest Before The Dawn For Facebook[0.0%]
# 2) Sure, Verizon blew $4.6 billion on AOL and Yahoo, but at least it isn't AT&T[10.0%]
# 3) Facebook testing search advertising as new revenue stream[13.6%]
# 4) Cryptoassets Explained: Civic[0.0%]
# 5) Portfolio Update: Stocks Getting Slammed As Dividends Shine Bright[70.0%]
#
#
# ******************************************************************************************************************************************************
# DONE

# %% [markdown]
# ## 7) StockTwits and Sentiment Analysis

# %%
for symbol in range(0,stock_dfs_length):
    df = stock_dfs[symbol]
    symbol = symbols[symbol]
    print(symbol, 'Stock Twits Feed','\n')
    bk.stock_twits(symbol)
    bk.line()
print('DONE')
# Out:
# AAPL Stock Twits Feed
#
# 1) $AAPL They gonna show that live debate all week now...hehe![17.0%]
# 2) $AAPL $GOOGL $FB $NFLX $AMZN[0.0%]
# 3) $AAPL Anyone here remember when Cramer whispered on his show it was going to $290. What a clown.[0.0%]
# 4) $AAPL WOW!...This was someday...have to get thru this Qualmcom ploy...hope everyone made bank...off to AH![0.0%]
# 5) $AAPL Outta here till tommo[0.0%]
# 6) $AAPL Some one brought $439167960 Dollors on last second WOW. 2614095 Share[3.3%]
# 7) $AAPL maybe Democrats can help control the 🤡[0.0%]
# 8) $SPX $AAPL $AMZN $WYNN $GE $GM $CRM Actionable Options.[0.0%]
# 9) $AAPL can this go over 170 tomorrow?[0.0%]
# 10) $AAPL Buyers stepping in... let’s see a nicely Green Day tomorrow[-20.0%]
# 11) $GOOG $NFLX $AAPL $AMZN $FB
# If we could take the aapl fb and netflix out of FAANG we would be rolling.[0.0%]
# 12) $AAPL Oh no, Mouthpiece back on![0.0%]
# 13) $AMZN ~45pts thru open low. ~30pts bounce w/ SPY.
# $TSLA $NVDA $NFLX $AAPL Clean range today.[12.2%]
# 14) $AAPL Lots of work for 1$ bears,,, sheesh bear meat for breakfast was a good app!![100.0%]
# 15) $AAPL Looks at watch, ECG reading not looking good, Siri, call DOC, send reading![87.5%]
# 16) $SPY $AAPL $MSFT $QQQ dump into close 😤[0.0%]
# 17) Another leg down coming.Take profits $AAPL $NFLX $BABA $PYPL $GOOG $NVDA $JNJ $MU $TWLO $QQQ $MSFT $MA $V $AMD $SPY $SQ $AMZN $INTC $UNH $FB[-15.6%]
# 18) $AAPL started to death spiral. People buying dips and losing causing more dips and so on[50.0%]
# 19) $AAPL women and children first![31.2%]
# 20) $AAPL retail sales for American eagle after hours today, Nordstrom
# After hours tmrw, and Costco/adobe after hours Thursday. Amazon &amp; alibaba[0.0%]
# 21) $AAPL exit doors[0.0%]
# 22) $AAPL what scares me is after almost 30% loss since October people have been buying these &quot;dips&quot;. Unless you bought yesterday, all losses[0.0%]
# 23) $AAPL I respect apple for not putting out fluff PR to boost price. *cough* Funding secured *cough* every $TLRY AH news article *cough*[-10.0%]
# 24) Apple: Holiday Gifts https://seekingalpha.com/article/4227756?source=ansh $AAPL[0.0%]
# 25) $AAPL AH 170?[0.0%]
# 26) $AMZN $aapl everyone heading for the exits. Risk off given preview of the Pelosi Schumer showdown with Trump. Crazy times![-75.0%]
# 27) $AAPL Wait to their new watch saving lives stories start popping up...a watch saving lives...sounds innovative to me![38.1%]
# 28) Get your custom Breakpoint platform view.
#
# Subscribe : http://chartpack.breakpoint.report
#
# $FB $AAPL $AMZN $NFLX $GOOGL $GOOG $XLC $SPY $QQQ $DJIA[0.0%]
# 29) $AAPL Fleas. The Hedge Fund Computer sell programs are very very strong. 171.79 to 167 is brutal. Now punching in again. Blunt Force Fist.[-15.6%]
# 30) $AAPL I need 170 tomorrow[0.0%]
#
#
# Total Sentiment Score: 6.8
# ******************************************************************************************************************************************************
# FB Stock Twits Feed
#
# 1) $AAPL $GOOGL $FB $NFLX $AMZN[0.0%]
# 2) $FB well at least stayed green
# Welcome sight for very sore eyes
#  glad t[20.0%]
# 3) $FB $SPY Bearish ending will be another overnight full of calls for doom and gloom... followed by another non-doomsday come tomorrow.[10.8%]
# 4) $GOOG $NFLX $AAPL $AMZN $FB
# If we could take the aapl fb and netflix out of FAANG we would be rolling.[0.0%]
# 5) Another leg down coming.Take profits $AAPL $NFLX $BABA $PYPL $GOOG $NVDA $JNJ $MU $TWLO $QQQ $MSFT $MA $V $AMD $SPY $SQ $AMZN $INTC $UNH $FB[-15.6%]
# 6) $FB Definition of a Bull Trap[0.0%]
# 7) $FB end of day sell off[0.0%]
# 8) $FB[0.0%]
# 9) Get your custom Breakpoint platform view.
#
# Subscribe : http://chartpack.breakpoint.report
#
# $FB $AAPL $AMZN $NFLX $GOOGL $GOOG $XLC $SPY $QQQ $DJIA[0.0%]
# 10) $FB parabolic move initiated
#
# 5 month incremental parabolic history this year:
#
# Apr - Aug:  43%⬆️
#
# Aug - Dec:  43%⬇️
#
# ➕43% in the making[0.0%]
# 11) $FB looking decent since yesterday. Another higher high/low and over this level.[20.8%]
# 12) @SeanasinSean Just needs a double upgrade and another 9bil buyback!! lmao $FB prop the turd before the next dump![20.0%]
# 13) $FB entry on 1/18 calls @ .57 - bought on 12/10[0.0%]
# 14) $FB bought 12/18 calls on 11/19 @ 1.92. Sold half on 12/10 for 2.93.[-16.7%]
# 15) $FB closing price don’t matter Johnny will hit it tomorrow! Peace[0.0%]
# 16) $FB R.I.P the the bears this week is a moon shot $AMZN $AAPL 🚀🙏[0.0%]
# 17) $WMT Zuckerberg did this kind of selling on $FB before the stock crashed.[60.0%]
# 18) $AAPL Oh look! Someone took a picture of the market today! $GOOGL $FB $NFLX $AMZN[0.0%]
# 19) $FB yes I’m rdy for 144 close[0.0%]
# 20) $ROKU took out 36 $FB $CGC[0.0%]
# 21) $FB  Stock Is Not a Buy Just Yet, wait until it reaches $200 and then buy.[0.0%]
# 22) $FB 144 before close...!!![0.0%]
# 23) $FB #Facebook Stock Is Not a Buy Just Yet https://investorplace.com/2018/12/facebook-stock-is-not-a-buy-just-yet/[0.0%]
# 24) $FB Closing above 200MA for first time in a while on hourly chart. Might lead to short squeeze and rally.[8.3%]
# 25) $FB not completely convinced[-5.0%]
# 26) $AMZN Just like yesterday, we rally at the end, meaning tomorrow will be green again $AAPL $GOOGL $GOOG $BRK.B $BRK.A $SQ $PYPL $FB $NFLX[-20.0%]
# 27) $FB LET’S BREAK $144 ![0.0%]
# 28) My advice is always wait until 3:55pm unless you daytrading $SPY $QQQ $IWM $DIA watch $AAPL n $FB at those support lines[0.0%]
# 29) $FB ouch!![0.0%]
# 30) $FB forming a nice hammer candlestick eod[60.0%]
#
#
# Total Sentiment Score: 4.8
# ******************************************************************************************************************************************************
# DONE
